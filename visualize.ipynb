# %%
from graphbrain.notebook import blocks, vblocks
from graphbrain import hedge
from IPython.display import HTML

# %%
# intro example (simple)
fname = "pres_ex1" + ".html"
edge = "(chased/Pd.so.<f-----/en (the/Md/en cat/Cc.s/en) (the/Md/en mouse/Cc.s/en))"
blocks(hedge(edge))
# Out:
# <div style="background-color:#fcfcfc; padding:50px"><div style="display:table;border:2px solid #fdf6e3;background-color:#eee8d5;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#eee8d5;padding-left:5px"><div style="padding:5px;background-color:#cb4b16;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">chased</span><span style="color:#eee8d5;font-weight:lighter">/P.so</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#eee8d5;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="display:table;border:2px solid #fdf6e3;background-color:#268bd2;border-radius:10px;padding:8px"><div style="display:table-row"><div style="display: table-row; vertical-align: top;background-color:#268bd2;padding:5px"><div style="padding:5px;background-color:#dc322f;border:
# ...

# %%
text = """<div style="background-color:#fcfcfc; padding:50px"><div style="display:table;border:2px solid #fdf6e3;background-color:#eee8d5;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#eee8d5;padding-left:5px"><div style="padding:5px;background-color:#cb4b16;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">chased</span><span style="color:#eee8d5;font-weight:lighter">/P.so</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#eee8d5;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="display:table;border:2px solid #fdf6e3;background-color:#268bd2;border-radius:10px;padding:8px"><div style="display:table-row"><div style="display: table-row; vertical-align: top;background-color:#268bd2;padding:5px"><div style="padding:5px;background-color:#dc322f;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">the</span><span style="color:#eee8d5;font-weight:lighter">/M</span></div></div><div style="display: table-row; height:8px"></div><div style="display: table-row; vertical-align: top;background-color:#268bd2;padding:5px"><div style="display:table"><div style="display: table-row"><div style="padding:5px;background-color:#268bd2;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">cat</span><span style="color:#eee8d5;font-weight:lighter">/C</span></div></div></div></div></div></div></div><div style="width:5px"></div><div style="display: table-cell;vertical-align: middle"><div style="display:table;border:2px solid #fdf6e3;background-color:#268bd2;border-radius:10px;padding:8px"><div style="display:table-row"><div style="display: table-row; vertical-align: top;background-color:#268bd2;padding:5px"><div style="padding:5px;background-color:#dc322f;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">the</span><span style="color:#eee8d5;font-weight:lighter">/M</span></div></div><div style="display: table-row; height:8px"></div><div style="display: table-row; vertical-align: top;background-color:#268bd2;padding:5px"><div style="display:table"><div style="display: table-row"><div style="padding:5px;background-color:#268bd2;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">mouse</span><span style="color:#eee8d5;font-weight:lighter">/C</span></div></div></div></div></div></div></div></div></div></div></div></div>"""
html = HTML(text)
with open(fname, "w", encoding="utf-8") as f:
    f.write(html.data)

# %%
# intro example (simple)
fname = "ex1" + ".html"
edge = "((is/Mv.|f--3s-/en described/Pd.px.<pf----/en) webster/Cp.s/en (as/T/en ('s/Bp.am/en benefield/Cp.s/en boyfriend/Cc.s/en)))"
blocks(hedge(edge))
# Out:
# <div style="background-color:#fcfcfc; padding:50px"><div style="display:table;border:2px solid #fdf6e3;background-color:#eee8d5;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#eee8d5;padding-left:5px"><div style="display:table;border:2px solid #fdf6e3;background-color:#cb4b16;border-radius:10px;padding:8px"><div style="display:table-row"><div style="display: table-row; vertical-align: top;background-color:#cb4b16;padding:5px"><div style="padding:5px;background-color:#dc322f;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">is</span><span style="color:#eee8d5;font-weight:lighter">/M</span></div></div><div style="display: table-row; height:8px"></div><div style="display: table-row; vertical-align: top;background-color:#cb4b16;padding:5px"><div style="display:table"><div style="display: table-row"><div style="padding:5px;background-color:#cb4
# ...

# %%
text = """<div style="background-color:#fcfcfc; padding:50px"><div style="display:table;border:2px solid #fdf6e3;background-color:#eee8d5;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#eee8d5;padding-left:5px"><div style="display:table;border:2px solid #fdf6e3;background-color:#cb4b16;border-radius:10px;padding:8px"><div style="display:table-row"><div style="display: table-row; vertical-align: top;background-color:#cb4b16;padding:5px"><div style="padding:5px;background-color:#dc322f;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">is</span><span style="color:#eee8d5;font-weight:lighter">/M</span></div></div><div style="display: table-row; height:8px"></div><div style="display: table-row; vertical-align: top;background-color:#cb4b16;padding:5px"><div style="display:table"><div style="display: table-row"><div style="padding:5px;background-color:#cb4b16;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">described</span><span style="color:#eee8d5;font-weight:lighter">/P.px</span></div></div></div></div></div></div></div><div style="display: table-cell; vertical-align: middle;background-color:#eee8d5;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#268bd2;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">webster</span><span style="color:#eee8d5;font-weight:lighter">/C</span></div></div><div style="width:5px"></div><div style="display: table-cell;vertical-align: middle"><div style="display:table;border:2px solid #fdf6e3;background-color:#6c71c4;border-radius:10px;padding:8px"><div style="display:table-row"><div style="display: table-row; vertical-align: top;background-color:#6c71c4;padding:5px"><div style="padding:5px;background-color:#d33682;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">as</span><span style="color:#eee8d5;font-weight:lighter">/T</span></div></div><div style="display: table-row; height:8px"></div><div style="display: table-row; vertical-align: top;background-color:#6c71c4;padding:5px"><div style="display:table"><div style="display: table-row"><div style="display:table;border:2px solid #fdf6e3;background-color:#268bd2;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding-left:5px"><div style="padding:5px;background-color:#859900;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">'s</span><span style="color:#eee8d5;font-weight:lighter">/B.am</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#268bd2;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">benefield</span><span style="color:#eee8d5;font-weight:lighter">/C</span></div></div><div style="width:5px"></div><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#268bd2;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">boyfriend</span><span style="color:#eee8d5;font-weight:lighter">/C</span></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div>"""
html = HTML(text)
with open(fname, "w", encoding="utf-8") as f:
    f.write(html.data)

# %%
fname = "ex1_ch3" + ".html"
edge = "(explains/Pd.rs.|f--3s-/en ((were/Mv.<f-----/en made/P.px.<pf----/en) (the/Md/en (controversial/Ma/en investments/Cc.p/en)) (between/Tt/en (and/J/en 2007/C#/en 2009/C#/en))) panorama/Cp.s/en)"
blocks(hedge(edge))
# Out:
# <div style="background-color:#fcfcfc; padding:50px"><div style="display:table;border:2px solid #fdf6e3;background-color:#eee8d5;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#eee8d5;padding-left:5px"><div style="padding:5px;background-color:#cb4b16;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">explains</span><span style="color:#eee8d5;font-weight:lighter">/P.rs</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#eee8d5;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="display:table;border:2px solid #fdf6e3;background-color:#eee8d5;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#eee8d5;padding-left:5px"><div style="display:table;border:2px solid #f
# ...

# %%
text = """<div style="background-color:#fcfcfc; padding:50px"><div style="display:table;border:2px solid #fdf6e3;background-color:#eee8d5;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#eee8d5;padding-left:5px"><div style="padding:5px;background-color:#cb4b16;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">explains</span><span style="color:#eee8d5;font-weight:lighter">/P.rs</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#eee8d5;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="display:table;border:2px solid #fdf6e3;background-color:#eee8d5;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#eee8d5;padding-left:5px"><div style="display:table;border:2px solid #fdf6e3;background-color:#cb4b16;border-radius:10px;padding:8px"><div style="display:table-row"><div style="display: table-row; vertical-align: top;background-color:#cb4b16;padding:5px"><div style="padding:5px;background-color:#dc322f;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">were</span><span style="color:#eee8d5;font-weight:lighter">/M</span></div></div><div style="display: table-row; height:8px"></div><div style="display: table-row; vertical-align: top;background-color:#cb4b16;padding:5px"><div style="display:table"><div style="display: table-row"><div style="padding:5px;background-color:#cb4b16;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">made</span><span style="color:#eee8d5;font-weight:lighter">/P.px</span></div></div></div></div></div></div></div><div style="display: table-cell; vertical-align: middle;background-color:#eee8d5;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="display:table;border:2px solid #fdf6e3;background-color:#268bd2;border-radius:10px;padding:8px"><div style="display:table-row"><div style="display: table-row; vertical-align: top;background-color:#268bd2;padding:5px"><div style="padding:5px;background-color:#dc322f;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">the</span><span style="color:#eee8d5;font-weight:lighter">/M</span></div></div><div style="display: table-row; height:8px"></div><div style="display: table-row; vertical-align: top;background-color:#268bd2;padding:5px"><div style="display:table"><div style="display: table-row"><div style="display:table;border:2px solid #fdf6e3;background-color:#268bd2;border-radius:10px;padding:8px"><div style="display:table-row"><div style="display: table-row; vertical-align: top;background-color:#268bd2;padding:5px"><div style="padding:5px;background-color:#dc322f;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">controversial</span><span style="color:#eee8d5;font-weight:lighter">/M</span></div></div><div style="display: table-row; height:8px"></div><div style="display: table-row; vertical-align: top;background-color:#268bd2;padding:5px"><div style="display:table"><div style="display: table-row"><div style="padding:5px;background-color:#268bd2;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">investments</span><span style="color:#eee8d5;font-weight:lighter">/C</span></div></div></div></div></div></div></div></div></div></div></div></div><div style="width:5px"></div><div style="display: table-cell;vertical-align: middle"><div style="display:table;border:2px solid #fdf6e3;background-color:#6c71c4;border-radius:10px;padding:8px"><div style="display:table-row"><div style="display: table-row; vertical-align: top;background-color:#6c71c4;padding:5px"><div style="padding:5px;background-color:#d33682;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">between</span><span style="color:#eee8d5;font-weight:lighter">/T</span></div></div><div style="display: table-row; height:8px"></div><div style="display: table-row; vertical-align: top;background-color:#6c71c4;padding:5px"><div style="display:table"><div style="display: table-row"><div style="display:table;border:2px solid #fdf6e3;background-color:#268bd2;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding-left:5px"><div style="padding:5px;background-color:#b58900;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">and</span><span style="color:#eee8d5;font-weight:lighter">/J</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#268bd2;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">2007</span><span style="color:#eee8d5;font-weight:lighter">/C</span></div></div><div style="width:5px"></div><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#268bd2;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">2009</span><span style="color:#eee8d5;font-weight:lighter">/C</span></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div><div style="width:5px"></div><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#268bd2;border:2px solid #fdf6e3;border-radius:10px;text-align:center"><span style="color:#fdf6e3;font-weight:bold">panorama</span><span style="color:#eee8d5;font-weight:lighter">/C</span></div></div></div></div></div></div></div>"""
html = HTML(text)
with open(fname, "w", encoding="utf-8") as f:
    f.write(html.data)

# %%
fname = "ex2_ch3" + ".html"
edge = "((are/Mv.|f-----/en scheduled/Pd.px.<pf----/en) (the/Md/en (new/Ma/en elections/Cc.p/en)) ((to/Mi/en take/P.ox.-i-----/en) place/Cc.s/en (on/Tt/en (of/Br.ma/en (+/B.ma/. february/Cp.s/en 2/C#/en) (next/Ma/en year/Cc.s/en)))))"
vblocks(hedge(edge))
# Out:
# <div style="background-color:#fcfcfc; padding:50px"><div style="display:table;border:2px solid #fdf6e3;background-color:#eee8d5;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: top;background-color:#eee8d5;padding:5px"><div style="display:table;border:2px solid #fdf6e3;background-color:#cb4b16;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#cb4b16;padding-left:5px"><div style="padding:5px;background-color:#dc322f;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">are</span><span style="color:#eee8d5;font-weight:lighter">/M</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#cb4b16;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#cb4b16;border:2px solid #fdf6e3;borde
# ...

# %%
text = """<div style="background-color:#fcfcfc; padding:50px"><div style="display:table;border:2px solid #fdf6e3;background-color:#eee8d5;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: top;background-color:#eee8d5;padding:5px"><div style="display:table;border:2px solid #fdf6e3;background-color:#cb4b16;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#cb4b16;padding-left:5px"><div style="padding:5px;background-color:#dc322f;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">are</span><span style="color:#eee8d5;font-weight:lighter">/M</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#cb4b16;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#cb4b16;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">scheduled</span><span style="color:#eee8d5;font-weight:lighter">/P.px</span></div></div></div></div></div></div></div><div style="display: table-cell; vertical-align: top;background-color:#eee8d5;padding:5px"><div style="display:table-row"><div><div style="display:table;border:2px solid #fdf6e3;background-color:#268bd2;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding-left:5px"><div style="padding:5px;background-color:#dc322f;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">the</span><span style="color:#eee8d5;font-weight:lighter">/M</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="display:table;border:2px solid #fdf6e3;background-color:#268bd2;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding-left:5px"><div style="padding:5px;background-color:#dc322f;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">new</span><span style="color:#eee8d5;font-weight:lighter">/M</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#268bd2;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">elections</span><span style="color:#eee8d5;font-weight:lighter">/C</span></div></div></div></div></div></div></div></div></div></div></div></div><div style="height:5px"></div><div><div style="display:table;border:2px solid #fdf6e3;background-color:#eee8d5;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: top;background-color:#eee8d5;padding:5px"><div style="display:table;border:2px solid #fdf6e3;background-color:#cb4b16;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#cb4b16;padding-left:5px"><div style="padding:5px;background-color:#dc322f;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">to</span><span style="color:#eee8d5;font-weight:lighter">/M</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#cb4b16;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#cb4b16;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">take</span><span style="color:#eee8d5;font-weight:lighter">/P.ox</span></div></div></div></div></div></div></div><div style="display: table-cell; vertical-align: top;background-color:#eee8d5;padding:5px"><div style="display:table-row"><div><div style="padding:5px;background-color:#268bd2;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">place</span><span style="color:#eee8d5;font-weight:lighter">/C</span></div></div><div style="height:5px"></div><div><div style="display:table;border:2px solid #fdf6e3;background-color:#6c71c4;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#6c71c4;padding-left:5px"><div style="padding:5px;background-color:#d33682;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">on</span><span style="color:#eee8d5;font-weight:lighter">/T</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#6c71c4;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="display:table;border:2px solid #fdf6e3;background-color:#268bd2;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: top;background-color:#268bd2;padding:5px"><div style="padding:5px;background-color:#859900;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">of</span><span style="color:#eee8d5;font-weight:lighter">/B.ma</span></div></div><div style="display: table-cell; vertical-align: top;background-color:#268bd2;padding:5px"><div style="display:table-row"><div><div style="display:table;border:2px solid #fdf6e3;background-color:#268bd2;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding-left:5px"><div style="padding:5px;background-color:#859900;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">+</span><span style="color:#eee8d5;font-weight:lighter">/B.ma</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#268bd2;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">february</span><span style="color:#eee8d5;font-weight:lighter">/C</span></div></div><div style="width:5px"></div><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#268bd2;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">2</span><span style="color:#eee8d5;font-weight:lighter">/C</span></div></div></div></div></div></div></div><div style="height:5px"></div><div><div style="display:table;border:2px solid #fdf6e3;background-color:#268bd2;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding-left:5px"><div style="padding:5px;background-color:#dc322f;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">next</span><span style="color:#eee8d5;font-weight:lighter">/M</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#268bd2;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">year</span><span style="color:#eee8d5;font-weight:lighter">/C</span></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div>"""
html = HTML(text)
with open(fname, "w", encoding="utf-8") as f:
    f.write(html.data)

# %%
edge = "((var explains/Pd.rs.|f--3s-/en REL) (var ((were/Mv.<f-----/en made/P.px.<pf----/en) (the/Md/en (controversial/Ma/en investments/Cc.p/en)) (between/Tt/en (and/J/en 2007/C#/en 2009/C#/en))) ARG1) (var panorama/Cp.s/en ARG0))"
fname = "ex1_ch3_funcp" + ".html"
vblocks(hedge(edge))
# Out:
# <div style="background-color:#fcfcfc; padding:50px"><div style="display:table;border:2px solid #fdf6e3;background-color:#eee8d5;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: top;background-color:#eee8d5;padding:5px"><div style="display:table;border:2px solid #fdf6e3;background-color:#cb4b16;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#cb4b16;padding-left:5px"><div style="padding:5px;background-color:#b58900;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">var</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#cb4b16;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#cb4b16;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bol
# ...

# %%
text = """<div style="background-color:#fcfcfc; padding:50px"><div style="display:table;border:2px solid #fdf6e3;background-color:#eee8d5;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: top;background-color:#eee8d5;padding:5px"><div style="display:table;border:2px solid #fdf6e3;background-color:#cb4b16;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#cb4b16;padding-left:5px"><div style="padding:5px;background-color:#b58900;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">var</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#cb4b16;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#cb4b16;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">explains</span><span style="color:#eee8d5;font-weight:lighter">/P.rs</span></div></div><div style="width:5px"></div><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#b58900;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">REL</span></div></div></div></div></div></div></div><div style="display: table-cell; vertical-align: top;background-color:#eee8d5;padding:5px"><div style="display:table-row"><div><div style="display:table;border:2px solid #fdf6e3;background-color:#eee8d5;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: top;background-color:#eee8d5;padding:5px"><div style="padding:5px;background-color:#b58900;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">var</span></div></div><div style="display: table-cell; vertical-align: top;background-color:#eee8d5;padding:5px"><div style="display:table-row"><div><div style="display:table;border:2px solid #fdf6e3;background-color:#eee8d5;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: top;background-color:#eee8d5;padding:5px"><div style="display:table;border:2px solid #fdf6e3;background-color:#cb4b16;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#cb4b16;padding-left:5px"><div style="padding:5px;background-color:#dc322f;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">were</span><span style="color:#eee8d5;font-weight:lighter">/M</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#cb4b16;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#cb4b16;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">made</span><span style="color:#eee8d5;font-weight:lighter">/P.px</span></div></div></div></div></div></div></div><div style="display: table-cell; vertical-align: top;background-color:#eee8d5;padding:5px"><div style="display:table-row"><div><div style="display:table;border:2px solid #fdf6e3;background-color:#268bd2;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding-left:5px"><div style="padding:5px;background-color:#dc322f;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">the</span><span style="color:#eee8d5;font-weight:lighter">/M</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="display:table;border:2px solid #fdf6e3;background-color:#268bd2;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding-left:5px"><div style="padding:5px;background-color:#dc322f;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">controversial</span><span style="color:#eee8d5;font-weight:lighter">/M</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#268bd2;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">investments</span><span style="color:#eee8d5;font-weight:lighter">/C</span></div></div></div></div></div></div></div></div></div></div></div></div><div style="height:5px"></div><div><div style="display:table;border:2px solid #fdf6e3;background-color:#6c71c4;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#6c71c4;padding-left:5px"><div style="padding:5px;background-color:#d33682;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">between</span><span style="color:#eee8d5;font-weight:lighter">/T</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#6c71c4;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="display:table;border:2px solid #fdf6e3;background-color:#268bd2;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding-left:5px"><div style="padding:5px;background-color:#b58900;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">and</span><span style="color:#eee8d5;font-weight:lighter">/J</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#268bd2;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">2007</span><span style="color:#eee8d5;font-weight:lighter">/C</span></div></div><div style="width:5px"></div><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#268bd2;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">2009</span><span style="color:#eee8d5;font-weight:lighter">/C</span></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div><div style="height:5px"></div><div><div style="padding:5px;background-color:#b58900;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">ARG1</span></div></div></div></div></div></div></div><div style="height:5px"></div><div><div style="display:table;border:2px solid #fdf6e3;background-color:#268bd2;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding-left:5px"><div style="padding:5px;background-color:#b58900;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">var</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#268bd2;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">panorama</span><span style="color:#eee8d5;font-weight:lighter">/C</span></div></div><div style="width:5px"></div><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#b58900;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">ARG0</span></div></div></div></div></div></div></div></div></div></div></div></div>"""
html = HTML(text)
with open(fname, "w", encoding="utf-8") as f:
    f.write(html.data)

# %%
edge = "(explains/Pd.rs.|f--3s-/en ((were/Mv.<f-----/en (var made/P.px.<pf----/en REL)) (var (the/Md/en (controversial/Ma/en investments/Cc.p/en)) ARG0) (var (between/Tt/en (and/J/en 2007/C#/en 2009/C#/en)) ARG1)) panorama/Cp.s/en)"
fname = "ex2_ch3_funcp" + ".html"
vblocks(hedge(edge))
# Out:
# <div style="background-color:#fcfcfc; padding:50px"><div style="display:table;border:2px solid #fdf6e3;background-color:#eee8d5;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: top;background-color:#eee8d5;padding:5px"><div style="padding:5px;background-color:#cb4b16;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">explains</span><span style="color:#eee8d5;font-weight:lighter">/P.rs</span></div></div><div style="display: table-cell; vertical-align: top;background-color:#eee8d5;padding:5px"><div style="display:table-row"><div><div style="display:table;border:2px solid #fdf6e3;background-color:#eee8d5;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: top;background-color:#eee8d5;padding:5px"><div style="display:table;border:2px solid #fdf6e3;background-color:#cb4b16;border-radius:10px;padding:3px"><div style="display:table
# ...

# %%
text = """<div style="background-color:#fcfcfc; padding:50px"><div style="display:table;border:2px solid #fdf6e3;background-color:#eee8d5;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: top;background-color:#eee8d5;padding:5px"><div style="padding:5px;background-color:#cb4b16;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">explains</span><span style="color:#eee8d5;font-weight:lighter">/P.rs</span></div></div><div style="display: table-cell; vertical-align: top;background-color:#eee8d5;padding:5px"><div style="display:table-row"><div><div style="display:table;border:2px solid #fdf6e3;background-color:#eee8d5;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: top;background-color:#eee8d5;padding:5px"><div style="display:table;border:2px solid #fdf6e3;background-color:#cb4b16;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#cb4b16;padding-left:5px"><div style="padding:5px;background-color:#dc322f;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">were</span><span style="color:#eee8d5;font-weight:lighter">/M</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#cb4b16;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="display:table;border:2px solid #fdf6e3;background-color:#cb4b16;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#cb4b16;padding-left:5px"><div style="padding:5px;background-color:#b58900;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">var</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#cb4b16;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#cb4b16;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">made</span><span style="color:#eee8d5;font-weight:lighter">/P.px</span></div></div><div style="width:5px"></div><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#b58900;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">REL</span></div></div></div></div></div></div></div></div></div></div></div></div><div style="display: table-cell; vertical-align: top;background-color:#eee8d5;padding:5px"><div style="display:table-row"><div><div style="display:table;border:2px solid #fdf6e3;background-color:#268bd2;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: top;background-color:#268bd2;padding:5px"><div style="padding:5px;background-color:#b58900;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">var</span></div></div><div style="display: table-cell; vertical-align: top;background-color:#268bd2;padding:5px"><div style="display:table-row"><div><div style="display:table;border:2px solid #fdf6e3;background-color:#268bd2;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding-left:5px"><div style="padding:5px;background-color:#dc322f;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">the</span><span style="color:#eee8d5;font-weight:lighter">/M</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="display:table;border:2px solid #fdf6e3;background-color:#268bd2;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding-left:5px"><div style="padding:5px;background-color:#dc322f;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">controversial</span><span style="color:#eee8d5;font-weight:lighter">/M</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#268bd2;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">investments</span><span style="color:#eee8d5;font-weight:lighter">/C</span></div></div></div></div></div></div></div></div></div></div></div></div><div style="height:5px"></div><div><div style="padding:5px;background-color:#b58900;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">ARG0</span></div></div></div></div></div></div></div><div style="height:5px"></div><div><div style="display:table;border:2px solid #fdf6e3;background-color:#6c71c4;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: top;background-color:#6c71c4;padding:5px"><div style="padding:5px;background-color:#b58900;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">var</span></div></div><div style="display: table-cell; vertical-align: top;background-color:#6c71c4;padding:5px"><div style="display:table-row"><div><div style="display:table;border:2px solid #fdf6e3;background-color:#6c71c4;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#6c71c4;padding-left:5px"><div style="padding:5px;background-color:#d33682;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">between</span><span style="color:#eee8d5;font-weight:lighter">/T</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#6c71c4;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="display:table;border:2px solid #fdf6e3;background-color:#268bd2;border-radius:10px;padding:3px"><div style="display:table-row"><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding-left:5px"><div style="padding:5px;background-color:#b58900;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">and</span><span style="color:#eee8d5;font-weight:lighter">/J</span></div></div><div style="display: table-cell; vertical-align: middle;background-color:#268bd2;padding:5px"><div style="display:table-row"><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#268bd2;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">2007</span><span style="color:#eee8d5;font-weight:lighter">/C</span></div></div><div style="width:5px"></div><div style="display: table-cell;vertical-align: middle"><div style="padding:5px;background-color:#268bd2;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">2009</span><span style="color:#eee8d5;font-weight:lighter">/C</span></div></div></div></div></div></div></div></div></div></div></div></div><div style="height:5px"></div><div><div style="padding:5px;background-color:#b58900;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">ARG1</span></div></div></div></div></div></div></div></div></div></div></div></div><div style="height:5px"></div><div><div style="padding:5px;background-color:#268bd2;border:2px solid #fdf6e3;border-radius:10px"><span style="color:#fdf6e3;font-weight:bold">panorama</span><span style="color:#eee8d5;font-weight:lighter">/C</span></div></div></div></div></div></div></div>"""
html = HTML(text)
with open(fname, "w", encoding="utf-8") as f:
    f.write(html.data)
